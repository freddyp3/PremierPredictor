# %%
import requests

# %%
prem_data = requests.get("https://fbref.com/en/comps/9/Premier-League-Stats")

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(prem_data.text)
standings_table = soup.select('table.stats_table')[0]
links = standings_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
prem_data = requests.get(team_urls[0])

# %%
import pandas as pd
import io

html_content = io.StringIO(prem_data.text)
matches = pd.read_html(html_content, match="Scores & Fixtures")[0]

matches.head()
# Out:
#          Date   Time            Comp         Round  Day Venue Result   GF  \
# 0  2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1  2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2  2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3  2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4  2024-09-17  21:00    Champions Lg  League phase  Tue  Away      W  3.0
#
#     GA         Opponent   xG  xGA  Poss  Attendance          Captain  \
# 0  0.0     Ipswich Town  2.6  0.5  62.0     30014.0  Virgil van Dijk
# 1  0.0        Brentford  2.5  0.5  62.0     60017.0  Virgil van Dijk
# 2  0.0   Manchester Utd  1.8  1.4  47.0     73738.0  Virgil van Dijk
# 3  1.0  Nott'ham Forest  0.9  0.4  68.0     60344.0  Virgil van Dijk
# 4  1.0         it Milan  3.1  0.6  51.0     59826.0  Virgil van Dijk
#
#   Formation Opp Formation         Referee  Match Report Notes
# ...

# %%
soup = BeautifulSoup(prem_data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l]

# %%
prem_data = requests.get(f"https://fbref.com{links[0]}")

# %%
html_content = io.StringIO(prem_data.text)
shooting = pd.read_html(html_content, match="Shooting")[0]

shooting.head()
# Out:
#   For Liverpool                                                              \
#            Date   Time            Comp         Round  Day Venue Result   GF
# 0    2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1    2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2    2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3    2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4    2024-09-17  21:00    Champions Lg  League phase  Tue  Away      W  3.0
#
#                          ... Standard               Expected               \
#     GA         Opponent  ...     Dist   FK PK PKatt       xG npxG npxG/Sh
# 0  0.0     Ipswich Town  ...     14.8  0.0  0     0      2.6  2.6    0.15
# 1  0.0        Brentford  ...     13.6  1.0  0     0      2.5  2.5    0.14
# 2  0.0   Manchester Utd  ...     13.4  0.0  0     0      1.8  1.8    0.16
# ...

# %%
shooting.columns = shooting.columns.droplevel()

# %%
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")

# %%
years = list(range(2025, 2021, -1))
all_matches = []
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
import time
for year in years:
    prem_data = requests.get(standings_url)
    soup = BeautifulSoup(prem_data.text, "html.parser")
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")

        prem_data = requests.get(team_url)
        print(f"Fetching: {team_url}, Status Code: {prem_data.status_code}")

        if prem_data.status_code != 200:
            print(f"Failed to fetch {team_name} in {year}, skipping...")
            continue

        html_content = io.StringIO(prem_data.text)
        try:
            tables = pd.read_html(html_content)
            print(f"Tables found for {team_name} in {year}: {len(tables)}")
        except ValueError:
            print(f"No tables found for {team_name} in {year}, skipping...")
            continue

        try:
            matches = pd.read_html(io.StringIO(prem_data.text), match="Scores & Fixtures")[0]
        except ValueError:
            print(f"No 'Scores & Fixtures' table found for {team_name} in {year}, skipping...")
            continue

        soup = BeautifulSoup(prem_data.text, "html.parser")
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]

        if not links:
            print(f"No shooting data found for {team_name} in {year}, skipping...")
            continue

        prem_data = requests.get(f"https://fbref.com{links[0]}")
        html_content = io.StringIO(prem_data.text)
        
        try:
            shooting = pd.read_html(html_content, match="Shooting")[0]
            shooting.columns = shooting.columns.droplevel()
        except ValueError:
            print(f"No 'Shooting' table found for {team_name} in {year}, skipping...")
            continue

        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            print(f"Data merge failed for {team_name} in {year}, skipping...")
            continue
            
        team_data = team_data[team_data["Comp"] == "Premier League"]

        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)

        time.sleep(10)
# Out:
# Fetching: https://fbref.com/en/squads/822bd0ba/Liverpool-Stats, Status Code: 200
# Tables found for Liverpool in 2025: 14
# Fetching: https://fbref.com/en/squads/18bb7c10/Arsenal-Stats, Status Code: 200
# Tables found for Arsenal in 2025: 14
# Fetching: https://fbref.com/en/squads/e4a775cb/Nottingham-Forest-Stats, Status Code: 200
# Tables found for Nottingham Forest in 2025: 14
# Fetching: https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats, Status Code: 200
# Tables found for Manchester City in 2025: 14
# Fetching: https://fbref.com/en/squads/4ba7cbea/Bournemouth-Stats, Status Code: 200
# Tables found for Bournemouth in 2025: 14
# Fetching: https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats, Status Code: 200
# Tables found for Chelsea in 2025: 14
# Fetching: https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats, Status Code: 200
# Tables found for Newcastle United in 2025: 14
# Fetching: https://fbref.com/en/squads/fd962109/Fulham-Stats, Status Code: 200
# ...

# %%
len(all_matches)
# Out:
# 80

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1   2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2   2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3   2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 5   2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 38  2022-04-30  15:00  Premier League  Matchweek 35  Sat  Away      L    0
# 39  2022-05-08  14:00  Premier League  Matchweek 36  Sun  Home      L    0
# 40  2022-05-11  19:45  Premier League  Matchweek 21  Wed  Away      L    0
# 41  2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D    1
# 42  2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      L    0
#
# ...

# %%
match_df.to_csv("match_data.csv")
